# %% [markdown]
# <a href="https://colab.research.google.com/github/GaytriChoudhari/EDA-on-Telecom-Churn-Analysis/blob/main/EDA_on_Telecom_Churn_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** Gaytri Jagdish Choudhari

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Exploratory Data Analysis (EDA) is a crucial step in understanding the underlying patterns, relationships, and trends within a dataset. In the context of telecom churn analysis, EDA allows us to gain insights into the factors influencing customer attrition.
#  refers to the rate at which customers or subscribers discontinue their relationship with a company or stop using its products or services. It is also known as customer attrition or customer turnover. Churn can occur in various industries, including telecommunications, banking, software, e-commerce, and subscription-based services.
#  This summary provides an overview of the EDA conducted as part of a telecom churn analysis project, highlighting the key findings and implications.
#  Know Your Data
#
#
# *    Know The Dataset
#
# *   Understanding Your Variables
# *   Data Wrangling
#
#
# *   Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# "Develop a predictive model to identify customers who are likely to churn from a telecom service provider. The dataset contains information about customers' demographics, account details, usage patterns, and customer service interactions. The objective is to analyze the factors contributing to customer churn and build a model that can accurately predict churn behavior. The model should help the telecom company proactively identify at-risk customers and take appropriate measures to retain them, thereby reducing customer churn and improving overall business performance."

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The business objective for Telecom Churn Analysis are:
#
#
# *   Reduce customer churn rate and improve customer retention in the telecom industry.
# *   Identify the key factors influencing customer churn.
#
# *   Analyze customer behavior and usage patterns to identify early indicators of potential churn.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset

df= pd.read_csv("Telecom Churn.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look

df.head(5)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count

df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count

df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count

#Checking missing values in Telecom Churn dataset
print(df.isnull().sum())

#no missing value present in the Telecom Churn data
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %% [markdown]
# No missing value found in both train and test data set

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
#  Telecom churn refers to the phenomenon of customers switching from one telecom provider to another. Telecom companies often analyze churn data to understand the reasons behind customer attrition and develop strategies to reduce churn rates.In a telecom churn dataset contain various customer-related variables and churn-related information.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns

df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
# Dataset Describe

df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Here are some common variables typically found in a telecom churn dataset, along with their descriptions:
#
#
# *   STATE: 51 Unique States in United States of America.
#
# *   Account Length: Length of The Account.
#
#
# * Area Code: 415 relates to San Francisco,408 is of San Jose and 510 is of City of Oakland.
#
# *   International Plan: Yes Indicate International Plan is Present and No Indicates no subscription for International Plan.
#
# *   VoiceMail Plan: Yes Indicates Voicemail Plan is Present and No Indicates no subscription for VoiceMail Plan.
#
# *   Number vmail messages: Number of Voicemail Messages ranging from 0 to 50.
#
# *   Total day minutes: Total Number of Minutes Spent By Customers in Morning.
# *   Total day calls: Total Number of Calls made by Customer in Morning.
#
#
# *   Total day charge: Total Charge to the Customers in Morning.
#
#
# *   Total eve minutes: Total Number of Minutes Spent By Customers in Evening.
#
#
# *   Total eve calls: Total Number of Calls made by Customer in Evening.
#
#
# *   Total eve charge: Total Charge to the Customers in Morning.
#
#
# *   Total night minutes: Total Number of Minutes Spent By Customers in the Night.
#
# *   Total night calls Total night calls: Total Number of Calls made Customer in Night.
#
#
# *   Total night charge: Total Charge to the Customers in Night.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

# Iterate over each column in the DataFrame
for column in df.columns:
    unique_values = df[column].unique()
    print(f"Unique values for {column}:")
    print(unique_values)
    print()
# Out:
# Unique values for State:
# ['KS' 'OH' 'NJ' 'OK' 'AL' 'MA' 'MO' 'LA' 'WV' 'IN' 'RI' 'IA' 'MT' 'NY'
#  'ID' 'VT' 'VA' 'TX' 'FL' 'CO' 'AZ' 'SC' 'NE' 'WY' 'HI' 'IL' 'NH' 'GA'
#  'AK' 'MD' 'AR' 'WI' 'OR' 'MI' 'DE' 'UT' 'CA' 'MN' 'SD' 'NC' 'WA' 'NM'
#  'NV' 'DC' 'KY' 'ME' 'MS' 'TN' 'PA' 'CT' 'ND']
#
# Unique values for Account length:
# [128 107 137  84  75 118 121 147 117 141  65  74 168  95  62 161  85  93
#   76  73  77 130 111 132 174  57  54  20  49 142 172  12  72  36  78 136
#  149  98 135  34 160  64  59 119  97  52  60  10  96  87  81  68 125 116
#   38  40  43 113 126 150 138 162  90  50  82 144  46  70  55 106  94 155
#   80 104  99 120 108 122 157 103  63 112  41 193  61  92 131 163  91 127
#  110 140  83 145  56 151 139   6 115 146 185 148  32  25 179  67  19 170
#  164  51 208  53 105  66  86  35  88 123  45 100 215  22  33 114  24 101
#  143  48  71 167  89 199 166 158 196 209  16  39 173 129  44  79  31 124
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# Replace missing values with 0
df.fillna(0, inplace=True)

# %%
# Display the first few rows of the DataFrame
df.head()

# Generate summary statistics of the numerical columns
df.describe()

# Count the occurrences of each state
df['State'].value_counts()

# Calculate the average total day minutes for churned and non-churned customers
df.groupby('Churn')['Total day minutes'].mean()
# Out:
# Churn
# False    175.175754
# True     206.914079
# Name: Total day minutes, dtype: float64

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
#  It groups the DataFrame by the 'Churn' column and then calculates the mean of the 'Total day minutes' column for each group. This analysis helps in understanding if there is any significant difference in the usage patterns between churned and non-churned customers.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %% [markdown]
# Our target variable has two categories which include True and False values. True = Customer will move or churn out. False = Customer won’t move We can clearly see that our data is highly imbalanced. The occurrence of false is higher than True. There are 2850 (85.51% ) customers who churn out and 483 (14.49%) customers retained.

# %%
# Chart - 1 visualization code
#Target Variable data distribution
plt.figure(figsize=(6,6))
sns.countplot(x = df.Churn,palette='deep')
plt.xlabel('Customer churn', fontsize= 12)
plt.ylabel('Count', fontsize= 12)
plt.title("Distribution of Customer Churning ",fontsize= 20)
plt.show()

# %% [markdown]
# It is clear that we have a Class Imbalance problem

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart used in the code snippet, sns.countplot(), was chosen to visualize the distribution of the target variable, which is the "Customer Churn" in this case. Here's the rationale behind selecting this chart:
#
# Target Variable: The target variable in this scenario is "Customer Churn," which is a binary variable indicating whether a customer has churned or not. Counting the occurrences of each class (churned or not churned) provides valuable insights into the data distribution.
#
# Countplot: The sns.countplot() function from the Seaborn library is suitable for visualizing the distribution of categorical variables. It displays the count of each category on the y-axis, making it an effective choice for showing the frequency or proportion of churned and non-churned customers.
#
# Clear and Concise: The countplot provides a straightforward representation of the number of occurrences for each class. It is easy to interpret and understand the distribution of churned and non-churned customers.
#
# Palette: The 'deep' palette used in the code snippet provides distinct colors for each category, making it visually appealing and easier to differentiate between the churned and non-churned categories.
#
# Axes Labels and Title: The x-axis is labeled as "Customer churn" to indicate the target variable being represented, and the y-axis represents the count of customers. The title "Distribution of Customer Churning" summarizes the purpose of the visualization.
#
# By using the countplot, you can quickly observe and compare the number of churned and non-churned customers, providing an initial understanding of the data distribution for the target variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the provided chart, the insights that can be derived are as follows:
#
# Imbalanced Classes: The chart reveals the distribution of customer churn in the dataset. It indicates whether the classes (churned and non-churned) are balanced or imbalanced. If one class significantly dominates the other, it suggests an imbalanced dataset, which may require special considerations during analysis.
#
# Churned vs. Non-Churned: The countplot clearly displays the number of customers in each category. By comparing the heights of the bars, you can observe the relative frequency of churned and non-churned customers. This information helps in understanding the proportion of customers who have churned compared to those who have not.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights from the chart can contribute to creating a positive business impact by providing a clear understanding of the distribution of customer churn. However, there might not be direct positive or negative impacts solely based on the chart itself. The specific business impact and implications would depend on further analysis, context, and the actions taken based on the insights gained.
#
# That said, here are some potential scenarios where the insights may have positive or negative implications:
#
# Positive Business Impact:
#
# Strategy Development: The insights gained from the chart can guide the development of targeted strategies to reduce customer churn. Understanding the proportion of churned customers can help in identifying areas for improvement and implementing retention initiatives to increase customer loyalty.
#
# Customer Segmentation: Analyzing the distribution of churned and non-churned customers can assist in segmenting the customer base. By identifying characteristics or patterns associated with churn, businesses can tailor their marketing, communication, and customer service efforts to specific segments, leading to better customer satisfaction and retention.
#
# Product and Service Enhancements: A clear understanding of the distribution of customer churn can reveal potential pain points or dissatisfaction with specific products or services. This insight can drive efforts to improve and enhance offerings, address customer concerns, and increase overall customer satisfaction.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
#Groupby --> size to represent ---> unstack the category
#train.groupby(["state", "Churn"]).size().unstack(level=-1).head()

#Relationational bar graph for checking data distribution with respect to target variable
def diff_bar(x,y):

    df.groupby([x,y]).size().unstack(level=-1).plot(kind='bar', figsize=(35,10))
    plt.xlabel(x,fontsize= 25)
    plt.ylabel('count',fontsize= 25)
    plt.legend(loc=0,fontsize= 25)
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)
    plt.title("{X} Vs {Y}".format(X=x,Y=y),fontsize = 40)
    plt.show()

# %% [markdown]
# State Wise Churn Analysis

# %%
#State Wise Churning of customer
diff_bar('State','Churn')

# %% [markdown]
# Most of the churned customers are from 415 area.

# %%
#area_code Wise Churning of customer
diff_bar('Area code','Churn')

# %% [markdown]
# Churn rate is more with customer using international plan. As only 323 customer using International plan and 137 churning out of them

# %%
#International_Plan Wise Churning of customer
diff_bar('International plan','Churn')

# %% [markdown]
# 922 customer using voice mail plan and 80 out of them are churning

# %%
#No. of Customer Churning and had a Voice mail plan
diff_bar('Voice mail plan','Churn')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart chosen in the given code is a bar graph. The purpose of this chart is to visually represent the distribution of data with respect to the target variable.
#
# Bar graphs are commonly used to display categorical data and compare the frequency or count of different categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The code the groupby function to group the data by two variables, "state" and "Churn". Then, it uses the size function to count the number of occurrences in each group. Finally, it uses unstack to pivot the data, representing the "Churn" categories as separate columns.
#
# The resulting chart is a bar graph that displays the distribution of the data with respect to the target variable ("Churn") across different states. Each bar represents the count of churned and non-churned customers in each state.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# the gained insights from the chart can have a positive business impact by enabling targeted retention strategies and providing region-specific insights. However, negative growth can occur if the insights reveal significant churn challenges or outliers that require focused efforts to address the underlying issues. The specific impact depends on the business's ability to leverage the insights and implement effective retention initiatives.

# %% [markdown]
# #### Chart - 3

# %% [markdown]
# In this we are going to see churn rate of churning percentage

# %%
# Chart - 3 visualization code

df ['Churn'].value_counts().plot.pie(explode=[0.05,0.05], autopct='%1.1f%%',  startangle=90,shadow=True, figsize=(8,8))
plt.title('Pie Chart for Churn')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart chosen in this case is a pie chart, which is suitable for visualizing the distribution of a categorical variable, in this instance, the "Churn" variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pie chart displays the proportion or percentage distribution of churned.Churn percentage rate: The pie chart allows for a quick understanding of the overall churn rate by comparing the sizes of the churned and non-churned slices. The larger the churned slice, the higher the churn rate in the dataset.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights from the pie chart can potentially help create a positive business impact, as they provide information about the distribution of the target variable ("Churn").

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code

sns.countplot(x='State', hue="Churn", data= df)
plt.rcParams['figure.figsize'] = (22, 7)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The countplot is a type of bar plot that displays the count of observations in each category using bars. It is suitable for visualizing the distribution of a categorical variable

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Relationship between Churn and State: By examining the distribution of churned and non-churned customers for each state, you can gain insights into how customer churn varies across different regions. This can help in understanding any associations or correlations between the state variable and churn.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# yes,create a positive business impact.It  reveals states with consistently higher churn rates, it provides an opportunity to focus on those states and develop targeted strategies to reduce churn. By addressing the underlying reasons for customer churn in those specific regions, the business can implement retention initiatives tailored to the needs and preferences of customers in those states. This can lead to improved customer satisfaction, increased loyalty, and reduced churn, ultimately resulting in positive business impact.

# %% [markdown]
# #### Chart - 5

# %% [markdown]
# As soon as we get the percentage let us see top 10 states who are moving towards churn

# %%
# Chart - 5 visualization code
plt.rcParams['figure.figsize'] = (12, 7)
color = plt.cm.copper(np.linspace(0, 0.5, 20))
((df.groupby(['State'])['Churn'].mean())*100).sort_values(ascending = False).head(10).plot.bar(color = ['violet','indigo','b','g','y','orange','r'])
plt.title(" State with most churn percentage", fontsize = 20)
plt.xlabel('state', fontsize = 15)
plt.ylabel('percentage', fontsize = 15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The chosen bar chart effectively represents the top churn states and their corresponding churn percentages, allowing for a quick and easy understanding of the states with the highest churn rates. It provides a clear visualization of the data and helps in identifying patterns or trends in churn behavior across different states.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  The chart provides valuable insights by highlighting the states with the highest churn percentages, facilitating a comparative analysis of churn rates across different regions. This information can be used to prioritize strategies and initiatives to reduce churn and improve customer retention in the identified states.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, create a positive business impact. Competitive Analysis: The insights gained from the chart can help businesses compare their churn rates with those of competitors in different states. If certain states have notably higher churn percentages, it indicates an area of improvement. By benchmarking against competitors and identifying best practices in low churn states, businesses can implement strategies to enhance customer loyalty, gain a competitive edge, and drive positive growth.

# %% [markdown]
# #### Chart - 6

# %% [markdown]
# Here we can see states NJ ans CA have same churn percentage. plot churn percentage pi plot of CA state for that we have to take CA state seperate

# %%
# Chart - 6 visualization code

state_CA =df[df['State']=='CA']

# %%
state_CA
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 61      CA             116        415                 No             Yes
# 131     CA              75        408                 No              No
# 356     CA             124        408                Yes              No
# 372     CA             151        415                Yes              No
# 496     CA              93        415                 No             Yes
# 654     CA              96        510                 No             Yes
# 655     CA              79        510                 No              No
# 765     CA             113        415                 No              No
# 862     CA              75        510                 No             Yes
# 954     CA             158        510                 No              No
# 1038    CA             112        415                 No              No
# 1158    CA              60        415                Yes              No
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It filters the DataFrame df to create a new DataFrame state_CA that contains data only for the state of  CA.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Churn Analysis: You can analyze the churn patterns within the state of California. By examining the Churn column in the state_CA DataFrame, you can calculate churn rates, identify factors contributing to churn, and compare churn behavior with other states

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# state_CA DataFrame can potentially help in creating a positive business impact.Identifying Market Opportunities: Analyzing the market trends, competition, and customer needs within California can reveal potential market opportunities. By identifying unmet needs or underserved segments, businesses can position themselves strategically to tap into these opportunities, leading to positive business growth.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

state_CA ['Churn'].value_counts().plot.pie(explode=[0.05,0.05], autopct='%1.1f%%',  startangle=90,shadow=True, figsize=(10,10))
plt.title('Pie Chart for Churn values')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart chosen  is a pie chart that represents the distribution of churn values in percentage.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  The pie chart visually represents the distribution of churn values and  It provides insights into the proportion of churned and non-churned customers in the dataset.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes it gives a positive business impact.The pie chart provides a clear visualization of the churn distribution within the state of California. By understanding the proportion of churned and non-churned customers, businesses can gain insights into the magnitude and impact of customer attrition. This understanding can help in developing targeted strategies to reduce churn and improve customer retention, leading to a positive business impact.

# %% [markdown]
# #### Chart - 8

# %% [markdown]
# As we see top 10 states ehich are moving towards churn let us see last 10 states which are moving towards churn

# %%
# Chart - 8 visualization code

plt.rcParams['figure.figsize'] = (12, 7)
color = plt.cm.copper(np.linspace(0, 0.5, 20))
((df.groupby(['State'])['Churn'].mean())*100).sort_values(ascending = True).head(10).plot.bar(color = ['b','indigo','violet','orange','y','g','r'])
plt.title(" State with least churn percentage", fontsize = 20)
plt.xlabel('state', fontsize = 25)
plt.ylabel('percentage', fontsize = 15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart representing the states with the least churn percentages.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Comparative Analysis: By comparing the lengths of the bars representing different states, it becomes evident which states have a lower churn percentage compared to others. This analysis helps identify regions that have implemented effective customer retention strategies or have favorable market conditions that contribute to reduced churn.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, It creating a positive business impact. Identify Successful Strategies: The bar chart highlights states with the least churn percentages, indicating regions that have been successful in retaining customers. By analyzing these states, businesses can gain insights into the strategies, policies, or initiatives that contribute to lower churn. Implementing similar practices in other regions may lead to improved customer retention and positive business impact.

# %% [markdown]
# #### Chart - 9

# %% [markdown]
# From graph we can see least percentage of cgurn is in state HI let us plot churn percentage plot for HI

# %%
# Chart - 9 visualization code
state_HI =df[df['State']=='HI']

# %%
state_HI ['Churn'].value_counts().plot.pie(explode=[0.05,0.05], autopct='%1.1f%%',  startangle=90,shadow=True, figsize=(10,10))
plt.title('Pie Chart for Churn values for state HI')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart chosen is a pie chart that represents the distribution of churn values in percentage.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# By analyzing the pie chart, you can gain insights into the churn patterns specific to the state. These insights can help businesses understand the level of customer attrition, assess the effectiveness of customer retention strategies in the region, and make informed decisions to improve customer satisfaction and reduce churn.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights from analyzing the churn values for the (state_HI) can potentially help create a positive business impact. Understanding Churn Distribution: The pie chart provides insights into the distribution of churned and non-churned customers in the state of HI. By analyzing the proportions and percentages of churned customers, businesses can understand the magnitude of churn and assess the impact on their customer base.

# %% [markdown]
# #### Chart - 10

# %% [markdown]
# For custumers to churn there may be more reasons one of the reason is Rates of calls let us compare all call rate

# %%
# Chart - 10 visualization code
day_mean = df['Total day charge'].mean()/df['Total day minutes'].mean()
eve_mean = df['Total eve charge'].mean()/df['Total eve minutes'].mean()
night_mean = df['Total night charge'].mean()/df['Total night minutes'].mean()
int_mean = df['Total intl charge'].mean()/df['Total intl minutes'].mean()

# %%
print([day_mean,eve_mean,night_mean,int_mean])
# Out:
# [0.17000300739130672, 0.08500104871485778, 0.04500041448440008, 0.2700500279887107]

# %%
sns.barplot(x=['Day','Evening','Night','International'],y=[day_mean,eve_mean,night_mean,int_mean])
# Out:
# <Axes: >

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  The chosen bar plot effectively visualizes the average charges per minute for different time periods, enabling easy comparison and interpretation of the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Relative Comparison: By comparing the calculated average charge per minute for different time periods, we can gain insights into the relative pricing or cost differences. The values obtained provide a comparison of the average charges per minute between the different time periods.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights from the given code can potentially help create a positive business impact.
#
# Understanding Cost Efficiency: The calculated values, such as day_mean, eve_mean, night_mean, and int_mean, provide insights into the average charge per minute for different time periods and international calls. This understanding of cost efficiency can help businesses optimize their pricing strategies, identify potential areas for cost reduction, and improve customer satisfaction.

# %% [markdown]
# #### Chart - 11

# %% [markdown]
# From graph we can see that International plans have more rate as compare to oters. By putting Bar plot in total minutes and state we can see how many minutes are used in day. As well as we will put multi-line plot in between Total day minutes, Total eve minutes, Total night minutes, Total intl minutes

# %%
# Chart - 11 visualization code

avg_total_day_minutes = df.groupby(['State'])['Total day minutes'].mean()

# %%
avg_total_day_minutes
# Out:
# State
# AK    178.384615
# AL    186.010000
# AR    176.116364
# AZ    171.604688
# CA    183.564706
# CO    178.712121
# CT    175.140541
# DC    171.379630
# DE    174.583607
# FL    179.533333
# GA    185.025926
# HI    175.962264
# IA    177.613636
# ID    178.619178
# IL    173.591379
# IN    196.525352
# KS    191.555714
# KY    173.754237
# LA    178.376471
# MA    180.103077
# MD    197.228571
# ME    185.262903
# MI    180.593151
# MN    183.354762
# MO    170.506349
# MS    177.929231
# MT    174.007353
# NC    185.145588
# ND    187.338710
# NE    177.465574
# NH    177.328571
# NJ    196.225000
# NM    171.429032
# NV    176.425758
# NY    175.114458
# OH    183.274359
# OK    179.909836
# OR    176.246154
# PA    188.375556
# RI    167.478462
# SC    166.441667
# SD    189.690000
# TN    175.771698
# TX    181.516667
# UT    183.569444
# VA    177.244156
# VT    182.031507
# WA    178.742424
# WI    179.130769
# WV    173.950943
# WY    180.170130
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In that avg_total_day_minutes is a variable that calculates the average total day minutes for each state in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insight found from the given code is the average total day minutes for each state in the dataset. By grouping the data by state and calculating the mean of the 'Total day minutes' column, the code provides the average number of minutes spent on daytime calls for each state.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from calculating the average total day minutes for each state (avg_total_day_minutes) can potentially help create a positive business impact.
#
# Identify High-Engagement States: By analyzing the average total day minutes, you can identify states where customers tend to spend more time on daytime calls. This information can be valuable for targeted marketing campaigns, customer retention strategies, and resource allocation. States with higher average total day minutes may indicate a higher level of customer engagement and potential opportunities for upselling or cross-selling additional services.

# %% [markdown]
# #### Chart - 12

# %% [markdown]
# Let see relation between churn and Total day minutes, Total eve minutes, Total night minutes and Total intl minutes with respect to Churn by scatter plot

# %%
# Chart - 12 visualization code

sns.scatterplot(x="Total day minutes", y="Total day charge", hue="Churn", data= df,palette='hls')
# Out:
# <Axes: xlabel='Total day minutes', ylabel='Total day charge'>

# %%
sns.scatterplot(x="Total eve minutes", y="Total eve charge", hue="Churn", data= df,palette='hls')
# Out:
# <Axes: xlabel='Total eve minutes', ylabel='Total eve charge'>

# %%
sns.scatterplot(x="Total night minutes", y="Total night charge", hue="Churn", data= df,palette='hls')
# Out:
# <Axes: xlabel='Total night minutes', ylabel='Total night charge'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot is a type of data visualization that displays the relationship between two numerical variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# By analyzing these scatter plots, you can gain insights into the relationships between call duration and charges, as well as how these variables differ between churned and non-churned customers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can contribute to a positive business impact:
#
# Identify customer behavior: By analyzing the relationships between call duration and charges, businesses can gain a deeper understanding of how customers utilize their services. This knowledge can help in designing tailored plans, optimizing pricing strategies, and offering personalized services to meet customer needs effectively.

# %% [markdown]
# #### Chart - 13

# %% [markdown]
# Let us see the relation between International plan, Voice mail plan and Customer service calls with respect to Churn by bar plot

# %%
# Chart - 13 visualization code

sns.countplot(x='International plan',hue="Churn",data = df)
# Out:
# <Axes: xlabel='International plan', ylabel='count'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart, a countplot with "International plan" on the x-axis and "Churn" on the hue, is chosen to visualize the relationship between the "International plan" feature and customer churn.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the countplot with "International plan" on the x-axis and "Churn" on the hue, we can derive the insights:
#
# Churn distribution by "International plan": The countplot shows the number of churned and non-churned customers categorized by whether they have an "International plan" or not. We can observe the count of customers with an "International plan" who churned and compare it to those who did not have an "International plan." This allows us to understand the churn behavior of customers based on their international plan subscription.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights from the countplot of "International plan" versus "Churn" can potentially help create a positive business impact. Here's the justification:
#
# Positive business impact: By analyzing the countplot, we can determine whether having an "International plan" has an impact on customer churn. If the count of churned customers is significantly lower for those with an "International plan," it suggests that offering this plan contributes to higher customer retention. This insight can be used to develop and refine strategies to promote the "International plan" and emphasize its value proposition to customers, ultimately leading to increased customer loyalty and positive business impact.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?

# %%
def diff_bar(x,y):

    df.groupby([x,y]).size().unstack(level=-1).plot(kind='bar',figsize=(35,10))
    plt.xlabel('x',fontsize = 25)
    plt.ylabel('count',fontsize = 25)
    plt.legend(loc=0,fontsize=25)
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)
    plt.title("Analyzing State Column",fontsize = 40)
    plt.show()

# %%
diff_bar('State','Customer service calls')

# %% [markdown]
# Based on the provided code, the diff_bar function generates a bar plot that analyzes the relationship between two variables, specifically 'State' and 'Customer service calls'. To suggest a business objectives are:
#
#
# *   Identify variations in customer service calls by state: The plot allows the client to observe and compare the count of customer service calls across different states. This insight can help the client identify states with higher or lower customer service call volumes.
#
# *   Evaluate customer service performance: By analyzing the distribution of customer service calls across states, the client can assess the effectiveness of their customer service operations. States with higher call volumes may indicate areas where customer issues or concerns need to be addressed more effectively.
#
# *  Identify potential improvement areas: If specific states consistently show a higher count of customer service calls, it suggests a potential need for improvement in service quality, product offerings, or communication channels in those states. The client can focus on enhancing customer satisfaction and reducing the number of service calls in these areas.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# After performing exploratory data analysis on the data set, this is what we have incurred from data:
#
#
# *   There are some states where the churn rate is high as compared to others may be due to low network coverage.
#
# *   Area code and Account length do not play any kind of role regarding the churn rate so,it's redundant data columns.
#
# *   In the International plan those customers who have this plan are churn more and also the international calling charges are also high so the customer who has the plan unsatisfied with network issues and high call charge.
#
# *  In the voice mail section when there are more than 20 voice-mail messages then there is a churn so it basically means that the quality of
# voice mail is not good.
#
#
# *   Total day call minutes, total day calls, Total day charge, Total eve minutes, Total eve calls, Total eve charge, Total night minutes, Total night calls, Total night charge, these columns didn't play any kind of role regarding the churn rate.
#
#
#
# *    In international calls data shows that the churn rate of those customers is high, those who take the international plan so it means that in international call charges are high also there is a call drop or network issue.
#
# *    In Customer service calls data shows us that whenever an unsatisfied customer called the service center the churn rate is high, which means the service center didn't resolve the customer issue.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
